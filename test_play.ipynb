# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
from src.game.connect_four import BoardState, ConnectFourGame

# %%
game = ConnectFourGame.as_new_game(verbose = True)

# %%
game.make_move(move = 1)
game.make_move(move = 2)
game.print_board()
# Out:
# GAME OVER - White won!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 game.make_move(move = 1)
# ----> 2 game.make_move(move = 2)
#       3 game.print_board()
#
# File c:\Users\Samue\gitrepos\connect_four\src\game\connect_four.py:4, in make_move(self, move)
#       2 from dataclasses import dataclass, field
#       3 from src.game.game_constants import BoardProperties
# ----> 4 from typing import TypeAlias
#       5 from numpy.typing import NDArray
#       6 from src.utils import FloatArray, IntArray
#
# ValueError: Game is already over
